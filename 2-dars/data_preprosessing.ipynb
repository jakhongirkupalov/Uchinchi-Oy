# %%
import pandas as pd
import logging


log_path =r'C:\Users\Jahongir\desktop\practise\Log\data_preprosessing.log'

logging.basicConfig(
    filename=log_path,
    filemode='a',
    format= "%(asctime)s-%(levelname)s-%(message)s",
    level=logging.INFO

)

try:
    logging.info('Csv fayl oqilmoqda....')
    df = pd.read_csv(r'C:\Users\Jahongir\desktop\practise\Data\Row_Data\youtube_full_dataset_10000.csv')
    logging.info(f'Fayl muaffaqqiyatli oqildi, satrlar soni: {len(df)}, ustunlar soni: {len(df.columns)}' )
except Exception as e:
    logging.error(f'Csv faylni oqishda xatolik yuz berdi:{e}')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8493 entries, 0 to 8492
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Video ID        8493 non-null   object
#  1   Video Title     8493 non-null   object
#  2   Channel         8492 non-null   object
#  3   Published Date  8493 non-null   object
#  4   Views           8493 non-null   int64
#  5   Likes           8493 non-null   int64
#  6   Comments        8493 non-null   int64
#  7   Subscribers     8493 non-null   int64
#  8   Channel Views   8493 non-null   int64
#  9   Country         8493 non-null   object
#  10  Region          8493 non-null   object
#  11  CategoryID      8493 non-null   int64
#  12  CategoryName    8493 non-null   object
# dtypes: int64(6), object(7)
# memory usage: 862.7+ KB

# %%
df['CategoryName'].unique()
# Out:
# array(['Gaming', 'People & Blogs', 'News & Politics', 'Entertainment',
#        'Science & Technology', 'Howto & Style', 'Autos & Vehicles',
#        'Music', 'Film & Animation', 'Sports', 'Comedy'], dtype=object)

# %%
import pandas as pd 

categories =['Gaming', 'People & Blogs', 'News & Politics', 'Entertainment',
       'Science & Technology', 'Howto & Style', 'Autos & Vehicles',
       'Music', 'Film & Animation', 'Sports', 'Comedy']

category_mapping = {cat: i for i, cat in enumerate(categories)}
df['CategoryName'] = df['CategoryName'].map(category_mapping)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8493 entries, 0 to 8492
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Video ID        8493 non-null   object
#  1   Video Title     8493 non-null   object
#  2   Channel         8492 non-null   object
#  3   Published Date  8493 non-null   object
#  4   Views           8493 non-null   int64
#  5   Likes           8493 non-null   int64
#  6   Comments        8493 non-null   int64
#  7   Subscribers     8493 non-null   int64
#  8   Channel Views   8493 non-null   int64
#  9   Country         8493 non-null   object
#  10  Region          8493 non-null   object
#  11  CategoryID      8493 non-null   int64
#  12  CategoryName    8493 non-null   int64
# dtypes: int64(7), object(6)
# memory usage: 862.7+ KB

# %%
import sys 
import os

source_path = os.path.abspath("../Source")
if source_path not in sys.path:
    sys.path.append(source_path)
print("Python executable: ", sys.executable)
print("Source path added:", source_path)

from preprosessing import Cleaner, Encoder, Scaler
# Out:
# Python executable:  c:\Users\Jahongir\AppData\Local\Programs\Python\Python313\python.exe
# Source path added: c:\Users\Jahongir\desktop\practise\Source

# %%
cleaner = Cleaner(df)
cleaner.tozala()
df_clean = cleaner.get_df()

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8493 entries, 0 to 8492
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Video ID        8493 non-null   object
#  1   Video Title     8493 non-null   object
#  2   Channel         8493 non-null   object
#  3   Published Date  8493 non-null   object
#  4   Views           8493 non-null   int64
#  5   Likes           8493 non-null   int64
#  6   Comments        8493 non-null   int64
#  7   Subscribers     8493 non-null   int64
#  8   Channel Views   8493 non-null   int64
#  9   Country         8493 non-null   object
#  10  Region          8493 non-null   object
#  11  CategoryID      8493 non-null   int64
#  12  CategoryName    8493 non-null   int64
# dtypes: int64(7), object(6)
# memory usage: 862.7+ KB

# %%
df_clean.to_csv(r"C:\Users\Jahongir\desktop\practise\Data\Preprosessing_Data\Missing_value_data.csv")

# %%
encoder = Encoder(df_clean, target_col="CategoryName")
encoder.encodla()
df_encoded = encoder.get_df()

# %%
scaler=Scaler(df,target_col="CategoryName")
scaler.scaling_qil()
df_scaled = scaler.get_df()
