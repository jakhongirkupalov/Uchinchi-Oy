# %%
# Imbalance dataset bilan model train qilinsa - quyidagi xolatlar ro'y beradi

# %%
# 1) kichik miqdordagi classlar ignore qilinadi
# 2) kichik classlar ustida natija past chiqadi 
# 3) umumiy natija baland bolishi mumkin, lekin biased performga sabab bo'ladi va overfitting bo'lib qoladi

# %%
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import PolynomialFeatures

# %%
np.random.seed(42)
x = np.linspace(-3, 3, 100)
y = 0.5 * x**2 +2+np.random.randn(100)*2

x = x.reshape(-1, 1)

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
print(y)
# Out:
# [ 7.49342831  6.04348976  7.4390869   9.01713409  5.33380528  5.16854886
#   8.63363224  6.852133    4.2240448   6.09751678  3.93863753  3.79076272
#   5.06656917  0.62017964  0.86467306  3.06137535  2.03540296  4.56834774
#   2.0062659   0.88384071  6.52955282  3.04018294  3.5239453   0.44021896
#   2.10544943  3.32423269  0.71224609  3.6811481   1.64766661  2.1884215
#   1.49493388  6.33311468  2.53544816  0.38457814  4.08632031 -0.05555323
#   2.75243793 -1.63237973 -0.41348872  2.59620181  3.64268155  2.4754271
#   1.87200922  1.47538673 -0.90148843  0.59750167  1.10122016  4.12572287
#   2.69136881 -1.52562117  2.64862708  1.23396767  0.65763442  3.24585028
#   4.09918913  3.91811579  0.39915908  1.48488103  2.7952174   4.11683865
#   1.24413086  1.87156543  0.07429057 -0.0577025   4.01118571  5.15371054
#   2.35597976  4.5695084   3.35183036  1.4081076   3.49460021  5.92501712
#   2.85809999  6.14352055 -2.1371027   4.83801988  3.46380947  2.79087419
# ...

# %%
# underfitting yaratamiz

# %%
poly = PolynomialFeatures(degree=1)
x_train_poly = poly.fit_transform(x_train)
x_test_poly = poly.transform(x_test)

model=LinearRegression()
model.fit(x_train_poly, y_train)
train_pred = model.predict(x_train_poly)
test_pred = model.predict(x_test_poly)

print("Train MSE:", mean_squared_error(y_train, train_pred))
print("Test MSE:", mean_squared_error(y_test, test_pred))
# Out:
# Train MSE: 5.708128241809962
# Test MSE: 4.400664049454962

# %%
# overfiting yaratamiz

# %%
poly = PolynomialFeatures(degree=12)
x_train_poly = poly.fit_transform(x_train)
x_test_poly = poly.transform(x_test)

model=LinearRegression()
model.fit(x_train_poly, y_train)
train_pred = model.predict(x_train_poly)
test_pred = model.predict(x_test_poly)

print("Train MSE:", mean_squared_error(y_train, train_pred))
print("Test MSE:", mean_squared_error(y_test, test_pred))
# Out:
# Train MSE: 2.9536792826213025
# Test MSE: 4.874569376026984

# %%
# GoodFit

# %%
poly = PolynomialFeatures(degree=3)
x_train_poly = poly.fit_transform(x_train)
x_test_poly = poly.transform(x_test)

model=LinearRegression()
model.fit(x_train_poly, y_train)
train_pred = model.predict(x_train_poly)
test_pred = model.predict(x_test_poly)

print("Train MSE:", mean_squared_error(y_train, train_pred))
print("Test MSE:", mean_squared_error(y_test, test_pred))
# Out:
# Train MSE: 3.264096034266294
# Test MSE: 2.4089886475841675

# %%
# SAMPLING

# %%
# Sampling ikki xil turda bo`ladi
# 1 - Oversampling
# 2 - Undersampling

# %%
# Oversampling bu - Minority classni ko`paytirish
# Undersampling  bu - Majority classni kamaytirish
